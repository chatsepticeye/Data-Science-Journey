# %%
import pandas as pd

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C'],index=['x','y','z'])

# %%
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['x', 'y', 'z']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df['A'].unique()
# Out:
# array([1, 4, 7])

# %%
coffee=pd.read_csv(r"C:\Users\Chaitanya\OneDrive\Desktop\NTIN SIR\coffee.csv")

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
olympic=pd.read_excel(r"C:\Users\Chaitanya\Downloads\olympics-data.xlsx")

# %%
olympic.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios=pd.read_csv(r"C:\Users\Chaitanya\Downloads\bios.csv")

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.to_excel
# Out:
# <bound method NDFrame.to_excel of         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[0:5]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25

# %%
coffee.loc[[0,1,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
coffee.loc[:,["Day","Units Sold"]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.iloc[:,[0,2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.index=coffee['Day']

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday    Espresso          40
# Thursday    Thursday       Latte          30
# Friday        Friday    Espresso          45
# Friday        Friday       Latte          35
# Saturday    Saturday    Espresso          45
# Saturday    Saturday       Latte          35
# Sunday        Sunday    Espresso          45
# Sunday        Sunday       Latte          35

# %%
coffee.loc['Monday':'Wednesday','Units Sold']
# Out:
# Day
# Monday       25
# Monday       15
# Tuesday      30
# Tuesday      20
# Wednesday    35
# Wednesday    25
# Name: Units Sold, dtype: int64

# %%
coffee = coffee.reset_index(drop=True)
coffee.at[0,'Units Sold']
# Out:
# np.int64(25)

# %%
coffee.iat[0,0]
# Out:
# 'Monday'

# %%
coffee.sort_values("Units Sold",ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
coffee.sort_values(["Coffee Type","Units Sold"],ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
for index,row in coffee.iterrows():
    print(index)
    print(row)
    print('\n\n\n')
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
#
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.loc[bios['height_cm']>215,['name','height_cm'] ]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios.loc[(bios['height_cm']>215) & (bios['born_country']=='USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios['name'].str.contains('Keith')]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['born_country'].isin(['USA','FRA','GRB']) & (bios['name'].str.startswith("Keith"))]
# Out:
#         athlete_id                name   born_date             born_city  \
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 62678        63144        Keith Notary  1960-01-22        Merritt Island
# 77550        78141       Keith Brantly  1962-05-23  Scott Air Force Base
# 84097        84766  Keith Christiansen  1944-07-14   International Falls
# 94646        95413         Keith Meyer  1938-06-20                Geneva
# 97499        98286       Keith Tkachuk  1972-03-28               Melrose
# 98068        98860       Keith Wegeman  1929-08-28                Denver
# 99921       100722        Keith Carney  1970-02-03            Providence
# 115973      117348     Keith Sanderson  1975-02-02              Plymouth
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
coffee['price']=4.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   4.99
# 1      Monday       Latte          15   4.99
# 2     Tuesday    Espresso          30   4.99
# 3     Tuesday       Latte          20   4.99
# 4   Wednesday    Espresso          35   4.99
# 5   Wednesday       Latte          25   4.99
# 6    Thursday    Espresso          40   4.99
# 7    Thursday       Latte          30   4.99
# 8      Friday    Espresso          45   4.99
# 9      Friday       Latte          35   4.99
# 10   Saturday    Espresso          45   4.99
# 11   Saturday       Latte          35   4.99
# 12     Sunday    Espresso          45   4.99
# 13     Sunday       Latte          35   4.99

# %%
import numpy as np
coffee['new__price']=np.where('Coffee Type'=='Espresso',3.99,5.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new__price
# 0      Monday    Espresso          25   4.99        5.99
# 1      Monday       Latte          15   4.99        5.99
# 2     Tuesday    Espresso          30   4.99        5.99
# 3     Tuesday       Latte          20   4.99        5.99
# 4   Wednesday    Espresso          35   4.99        5.99
# 5   Wednesday       Latte          25   4.99        5.99
# 6    Thursday    Espresso          40   4.99        5.99
# 7    Thursday       Latte          30   4.99        5.99
# 8      Friday    Espresso          45   4.99        5.99
# 9      Friday       Latte          35   4.99        5.99
# 10   Saturday    Espresso          45   4.99        5.99
# 11   Saturday       Latte          35   4.99        5.99
# 12     Sunday    Espresso          45   4.99        5.99
# 13     Sunday       Latte          35   4.99        5.99

# %%
coffee.drop(columns=['price'])
# Out:
#           Day Coffee Type  Units Sold  new__price
# 0      Monday    Espresso          25        5.99
# 1      Monday       Latte          15        5.99
# 2     Tuesday    Espresso          30        5.99
# 3     Tuesday       Latte          20        5.99
# 4   Wednesday    Espresso          35        5.99
# 5   Wednesday       Latte          25        5.99
# 6    Thursday    Espresso          40        5.99
# 7    Thursday       Latte          30        5.99
# 8      Friday    Espresso          45        5.99
# 9      Friday       Latte          35        5.99
# 10   Saturday    Espresso          45        5.99
# 11   Saturday       Latte          35        5.99
# 12     Sunday    Espresso          45        5.99
# 13     Sunday       Latte          35        5.99

# %%
coffee['revenue']=coffee['Units Sold']* coffee['price']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue
# 0      Monday    Espresso          25   4.99        5.99   124.75
# 1      Monday       Latte          15   4.99        5.99    74.85
# 2     Tuesday    Espresso          30   4.99        5.99   149.70
# 3     Tuesday       Latte          20   4.99        5.99    99.80
# 4   Wednesday    Espresso          35   4.99        5.99   174.65
# 5   Wednesday       Latte          25   4.99        5.99   124.75
# 6    Thursday    Espresso          40   4.99        5.99   199.60
# 7    Thursday       Latte          30   4.99        5.99   149.70
# 8      Friday    Espresso          45   4.99        5.99   224.55
# 9      Friday       Latte          35   4.99        5.99   174.65
# 10   Saturday    Espresso          45   4.99        5.99   224.55
# 11   Saturday       Latte          35   4.99        5.99   174.65
# 12     Sunday    Espresso          45   4.99        5.99   224.55
# ...

# %%
bios_new=bios.copy()

# %%
bios_new['first_name']=bios_new['name'].str.split(' ').str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.query('first_name =="Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 12.2+ MB

# %%
bios_new['born_datetime']=pd.to_datetime(bios_new['born_date'])

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 13.3+ MB

# %%
bios_new['born_year']=bios_new['born_datetime'].dt.year

# %%
bios_new[['name','born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bios_new.to_csv('./date/bios_new.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 bios_new.to_csv('./date/bios_new.csv',index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3989, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
# ...

# %%
bios['height_category']=bios['height_cm'].apply(lambda x:'Short' if x<165 else( 'AVERAGE' if x<185 else 'Tall'))

# %%
bios.head()

# %%
def categorize_athlete(row):
    if(row['height_cm']<175 and row['weight_kg']<70):
        return 'Leightweight'
    elif(row['height_cm']<180 and row['weight_kg']<=80):
        return 'Middleweight'
    else:
        return 'Heavyweight'
bios['Category']=bios.apply(categorize_athlete,axis=1)

# %%
bios.head()

# %%
# Load your main athlete data
bios = pd.read_excel(r"C:\Users\Chaitanya\Downloads\olympics-data.xlsx")

# Load the region mapping file (get this from Keith's GitHub)
nocs = pd.read_csv(r"C:\Users\Chaitanya\Downloads\noc_regions.csv")

# %%
# This is the exact code from the video
df = pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='left')

# Show the results
df.head()

# %%
bios_new.rename(columns={'region':'born_country_full'},inplace=True)

# %%
bios_new.head()

# %%
usa=bios[bios['born_country']=='USA'].copy()

# %%
gbr=bios[bios['born_country']=='GBR'].copy()

# %%
gbr.head()

# %%
usa.tail()

# %%
new_df=pd.concat([usa,gbr])

# %%
new_df.head()

# %%
results=pd.read_csv(r"C:\Users\Chaitanya\Downloads\results.csv")
combined_df=pd.merge(results,bios,on='athlete_id',how='left')

# %%
combined_df.head()

# %%
import numpy as np
coffee.loc[[0,1],'Units Sold']=np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue
# 0      Monday    Espresso         NaN   4.99        5.99   124.75
# 1      Monday       Latte         NaN   4.99        5.99    74.85
# 2     Tuesday    Espresso        30.0   4.99        5.99   149.70
# 3     Tuesday       Latte        20.0   4.99        5.99    99.80
# 4   Wednesday    Espresso        35.0   4.99        5.99   174.65
# 5   Wednesday       Latte        25.0   4.99        5.99   124.75
# 6    Thursday    Espresso        40.0   4.99        5.99   199.60
# 7    Thursday       Latte        30.0   4.99        5.99   149.70
# 8      Friday    Espresso        45.0   4.99        5.99   224.55
# 9      Friday       Latte        35.0   4.99        5.99   174.65
# 10   Saturday    Espresso        45.0   4.99        5.99   224.55
# 11   Saturday       Latte        35.0   4.99        5.99   174.65
# 12     Sunday    Espresso        45.0   4.99        5.99   224.55
# ...

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# price          0
# new__price     0
# revenue        0
# dtype: int64

# %%
coffee.fillna(coffee['Units Sold'].mean())
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue
# 0      Monday    Espresso        35.0   4.99        5.99   124.75
# 1      Monday       Latte        35.0   4.99        5.99    74.85
# 2     Tuesday    Espresso        30.0   4.99        5.99   149.70
# 3     Tuesday       Latte        20.0   4.99        5.99    99.80
# 4   Wednesday    Espresso        35.0   4.99        5.99   174.65
# 5   Wednesday       Latte        25.0   4.99        5.99   124.75
# 6    Thursday    Espresso        40.0   4.99        5.99   199.60
# 7    Thursday       Latte        30.0   4.99        5.99   149.70
# 8      Friday    Espresso        45.0   4.99        5.99   224.55
# 9      Friday       Latte        35.0   4.99        5.99   174.65
# 10   Saturday    Espresso        45.0   4.99        5.99   224.55
# 11   Saturday       Latte        35.0   4.99        5.99   174.65
# 12     Sunday    Espresso        45.0   4.99        5.99   224.55
# ...

# %%
##HANDLING NULL VALUES
import numpy as np
coffee.loc[[0,1],'Units Sold']=15

# %%
coffee.loc[[2,3],'Units Sold']=np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue
# 0      Monday    Espresso        15.0   4.99        5.99   124.75
# 1      Monday       Latte        15.0   4.99        5.99    74.85
# 2     Tuesday    Espresso         NaN   4.99        5.99   149.70
# 3     Tuesday       Latte         NaN   4.99        5.99    99.80
# 4   Wednesday    Espresso        35.0   4.99        5.99   174.65
# 5   Wednesday       Latte        25.0   4.99        5.99   124.75
# 6    Thursday    Espresso        40.0   4.99        5.99   199.60
# 7    Thursday       Latte        30.0   4.99        5.99   149.70
# 8      Friday    Espresso        45.0   4.99        5.99   224.55
# 9      Friday       Latte        35.0   4.99        5.99   174.65
# 10   Saturday    Espresso        45.0   4.99        5.99   224.55
# 11   Saturday       Latte        35.0   4.99        5.99   174.65
# 12     Sunday    Espresso        45.0   4.99        5.99   224.55
# ...

# %%
coffee['Units Sold']=coffee['Units Sold'].interpolate()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue
# 0      Monday    Espresso   15.000000   4.99        5.99   124.75
# 1      Monday       Latte   15.000000   4.99        5.99    74.85
# 2     Tuesday    Espresso   21.666667   4.99        5.99   149.70
# 3     Tuesday       Latte   28.333333   4.99        5.99    99.80
# 4   Wednesday    Espresso   35.000000   4.99        5.99   174.65
# 5   Wednesday       Latte   25.000000   4.99        5.99   124.75
# 6    Thursday    Espresso   40.000000   4.99        5.99   199.60
# 7    Thursday       Latte   30.000000   4.99        5.99   149.70
# 8      Friday    Espresso   45.000000   4.99        5.99   224.55
# 9      Friday       Latte   35.000000   4.99        5.99   174.65
# 10   Saturday    Espresso   45.000000   4.99        5.99   224.55
# 11   Saturday       Latte   35.000000   4.99        5.99   174.65
# 12     Sunday    Espresso   45.000000   4.99        5.99   224.55
# ...

# %%
coffee.loc[[2,3],'Units Sold']=np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue
# 0      Monday    Espresso        15.0   4.99        5.99   124.75
# 1      Monday       Latte        15.0   4.99        5.99    74.85
# 2     Tuesday    Espresso         NaN   4.99        5.99   149.70
# 3     Tuesday       Latte         NaN   4.99        5.99    99.80
# 4   Wednesday    Espresso        35.0   4.99        5.99   174.65
# 5   Wednesday       Latte        25.0   4.99        5.99   124.75
# 6    Thursday    Espresso        40.0   4.99        5.99   199.60
# 7    Thursday       Latte        30.0   4.99        5.99   149.70
# 8      Friday    Espresso        45.0   4.99        5.99   224.55
# 9      Friday       Latte        35.0   4.99        5.99   174.65
# 10   Saturday    Espresso        45.0   4.99        5.99   224.55
# 11   Saturday       Latte        35.0   4.99        5.99   174.65
# 12     Sunday    Espresso        45.0   4.99        5.99   224.55
# ...

# %%
coffee.dropna()
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue
# 0      Monday    Espresso        15.0   4.99        5.99   124.75
# 1      Monday       Latte        15.0   4.99        5.99    74.85
# 4   Wednesday    Espresso        35.0   4.99        5.99   174.65
# 5   Wednesday       Latte        25.0   4.99        5.99   124.75
# 6    Thursday    Espresso        40.0   4.99        5.99   199.60
# 7    Thursday       Latte        30.0   4.99        5.99   149.70
# 8      Friday    Espresso        45.0   4.99        5.99   224.55
# 9      Friday       Latte        35.0   4.99        5.99   174.65
# 10   Saturday    Espresso        45.0   4.99        5.99   224.55
# 11   Saturday       Latte        35.0   4.99        5.99   174.65
# 12     Sunday    Espresso        45.0   4.99        5.99   224.55
# 13     Sunday       Latte        35.0   4.99        5.99   174.65

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
#        Day Coffee Type  Units Sold  price  new__price  revenue
# 2  Tuesday    Espresso         NaN   4.99        5.99    149.7
# 3  Tuesday       Latte         NaN   4.99        5.99     99.8

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue
# 0      Monday    Espresso        15.0   4.99        5.99   124.75
# 1      Monday       Latte        15.0   4.99        5.99    74.85
# 4   Wednesday    Espresso        35.0   4.99        5.99   174.65
# 5   Wednesday       Latte        25.0   4.99        5.99   124.75
# 6    Thursday    Espresso        40.0   4.99        5.99   199.60
# 7    Thursday       Latte        30.0   4.99        5.99   149.70
# 8      Friday    Espresso        45.0   4.99        5.99   224.55
# 9      Friday       Latte        35.0   4.99        5.99   174.65
# 10   Saturday    Espresso        45.0   4.99        5.99   224.55
# 11   Saturday       Latte        35.0   4.99        5.99   174.65
# 12     Sunday    Espresso        45.0   4.99        5.99   224.55
# 13     Sunday       Latte        35.0   4.99        5.99   174.65

# %%
##AGGREGATING DATA
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Bodrogkisfalud        1
# Ternberg              1
# Klaus                 1
# Plaški                1
# Dulwich Hill          1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Pennsylvania             530
# Massachusetts            530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts().tail()
# Out:
# born_region
# South Dakota     27
# West Virginia    24
# Delaware         22
# North Dakota     16
# Wyoming          14
# Name: count, dtype: int64

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts().tail(25)
# Out:
# born_region
# Utah              91
# Missouri          91
# North Carolina    86
# Arizona           83
# New Hampshire     83
# Vermont           68
# Mississippi       66
# Alabama           64
# Kentucky          62
# Tennessee         62
# Nebraska          60
# Rhode Island      56
# Montana           55
# South Carolina    50
# Maine             50
# Alaska            45
# Arkansas          42
# Idaho             41
# New Mexico        38
# Nevada            36
# South Dakota      27
# West Virginia     24
# Delaware          22
# North Dakota      16
# Wyoming           14
# Name: count, dtype: int64

# %%
coffee['Units Sold']=coffee['Units Sold'].interpolate()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue
# 0      Monday    Espresso   15.000000   4.99        5.99   124.75
# 1      Monday       Latte   15.000000   4.99        5.99    74.85
# 2     Tuesday    Espresso   21.666667   4.99        5.99   149.70
# 3     Tuesday       Latte   28.333333   4.99        5.99    99.80
# 4   Wednesday    Espresso   35.000000   4.99        5.99   174.65
# 5   Wednesday       Latte   25.000000   4.99        5.99   124.75
# 6    Thursday    Espresso   40.000000   4.99        5.99   199.60
# 7    Thursday       Latte   30.000000   4.99        5.99   149.70
# 8      Friday    Espresso   45.000000   4.99        5.99   224.55
# 9      Friday       Latte   35.000000   4.99        5.99   174.65
# 10   Saturday    Espresso   45.000000   4.99        5.99   224.55
# 11   Saturday       Latte   35.000000   4.99        5.99   174.65
# 12     Sunday    Espresso   45.000000   4.99        5.99   224.55
# ...

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    246.666667
# Latte       203.333333
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type','Day']).agg({'Units Sold':'sum','price':'mean'})
# Out:
#                        Units Sold  price
# Coffee Type Day
# Espresso    Friday      45.000000   4.99
#             Monday      15.000000   4.99
#             Saturday    45.000000   4.99
#             Sunday      45.000000   4.99
#             Thursday    40.000000   4.99
#             Tuesday     21.666667   4.99
#             Wednesday   35.000000   4.99
# Latte       Friday      35.000000   4.99
#             Monday      15.000000   4.99
#             Saturday    35.000000   4.99
#             Sunday      35.000000   4.99
#             Thursday    30.000000   4.99
#             Tuesday     28.333333   4.99
#             Wednesday   25.000000   4.99

# %%
pivot=coffee.pivot(columns='Coffee Type',index='Day',values='revenue')

# %%
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         224.55  174.65
# Monday         124.75   74.85
# Saturday       224.55  174.65
# Sunday         224.55  174.65
# Thursday       199.60  149.70
# Tuesday        149.70   99.80
# Wednesday      174.65  124.75

# %%
pivot.sum
# Out:
# <bound method DataFrame.sum of Coffee Type  Espresso   Latte
# Day
# Friday         224.55  174.65
# Monday         124.75   74.85
# Saturday       224.55  174.65
# Sunday         224.55  174.65
# Thursday       199.60  149.70
# Tuesday        149.70   99.80
# Wednesday      174.65  124.75>

# %%
pivot.sum(axis=1)
# Out:
# Day
# Friday       399.2
# Monday       199.6
# Saturday     399.2
# Sunday       399.2
# Thursday     349.3
# Tuesday      249.5
# Wednesday    299.4
# dtype: float64

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios['born_date']=pd.to_datetime(bios['born_date'])

# %%
bios['month_born']=bios['born_date'].dt.month
bios['year_born']=bios['born_date'].dt.year
bios.groupby([bios['month_born'],bios['year_born']])['name'].count().reset_index().sort_values('name',ascending=False)
# Out:
#       month_born  year_born  name
# 124          1.0     1970.0   239
# 126          1.0     1972.0   229
# 129          1.0     1975.0   227
# 140          1.0     1986.0   227
# 139          1.0     1985.0   225
# ...          ...        ...   ...
# 1262         9.0     1852.0     1
# 1264         9.0     1854.0     1
# 1265         9.0     1855.0     1
# 1267         9.0     1857.0     1
# 1884        12.0     2006.0     1
#
# [1885 rows x 3 columns]

# %%
coffee['yesterday_revenue']=coffee['revenue'].shift(2)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue  \
# 0      Monday    Espresso   15.000000   4.99        5.99   124.75
# 1      Monday       Latte   15.000000   4.99        5.99    74.85
# 2     Tuesday    Espresso   21.666667   4.99        5.99   149.70
# 3     Tuesday       Latte   28.333333   4.99        5.99    99.80
# 4   Wednesday    Espresso   35.000000   4.99        5.99   174.65
# 5   Wednesday       Latte   25.000000   4.99        5.99   124.75
# 6    Thursday    Espresso   40.000000   4.99        5.99   199.60
# 7    Thursday       Latte   30.000000   4.99        5.99   149.70
# 8      Friday    Espresso   45.000000   4.99        5.99   224.55
# 9      Friday       Latte   35.000000   4.99        5.99   174.65
# 10   Saturday    Espresso   45.000000   4.99        5.99   224.55
# 11   Saturday       Latte   35.000000   4.99        5.99   174.65
# 12     Sunday    Espresso   45.000000   4.99        5.99   224.55
# ...

# %%
coffee['pct_change']=coffee['revenue']/coffee['yesterday_revenue']*100

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue  \
# 0      Monday    Espresso   15.000000   4.99        5.99   124.75
# 1      Monday       Latte   15.000000   4.99        5.99    74.85
# 2     Tuesday    Espresso   21.666667   4.99        5.99   149.70
# 3     Tuesday       Latte   28.333333   4.99        5.99    99.80
# 4   Wednesday    Espresso   35.000000   4.99        5.99   174.65
# 5   Wednesday       Latte   25.000000   4.99        5.99   124.75
# 6    Thursday    Espresso   40.000000   4.99        5.99   199.60
# 7    Thursday       Latte   30.000000   4.99        5.99   149.70
# 8      Friday    Espresso   45.000000   4.99        5.99   224.55
# 9      Friday       Latte   35.000000   4.99        5.99   174.65
# 10   Saturday    Espresso   45.000000   4.99        5.99   224.55
# 11   Saturday       Latte   35.000000   4.99        5.99   174.65
# 12     Sunday    Espresso   45.000000   4.99        5.99   224.55
# ...

# %%
bios['height_rank']=bios['height_cm'].rank()

# %%
bios
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.sort_values(['height_rank'],ascending=False)
# Out:
#         athlete_id                   name  born_date           born_city  \
# 89070        89782               Yao Ming 1980-09-12      Xuhui District
# 5781          5804         Tommy Burleson 1952-02-24           Crossnore
# 6978          7013        Arvydas Sabonis 1964-12-19              Kaunas
# 89075        89787         Roberto Dueñas 1975-11-01              Madrid
# 120266      122147           Zhang Zhaoxu 1987-11-18             Binzhou
# ...            ...                    ...        ...                 ...
# 145490      149217            Sin Ye-Chan 1995-06-13                 NaN
# 145491      149218          Matthew Wepke 1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez 1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova 1998-08-31    Dva Polya Artash
# 145499      149814          Bill Phillips 1913-07-15        Dulwich Hill
#
#                  born_region born_country                         NOC  \
# ...

# %%
bios.sort_values(['height_rank'])
# Out:
#         athlete_id                   name  born_date           born_city  \
# 28619        28832        Rosario Briones 1953-10-05     San Luis Potosí
# 4515          4530          Lyton Mphande 1963-05-14                 NaN
# 4516          4531          Helman Palije 1967-06-24                 NaN
# 4664          4681       Salvador Miranda 1949-09-13                 NaN
# 4517          4532         Boston Simbeye 1959-12-24                 NaN
# ...            ...                    ...        ...                 ...
# 145490      149217            Sin Ye-Chan 1995-06-13                 NaN
# 145491      149218          Matthew Wepke 1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez 1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova 1998-08-31    Dva Polya Artash
# 145499      149814          Bill Phillips 1913-07-15        Dulwich Hill
#
#                  born_region born_country                NOC  height_cm  \
# ...

# %%
coffee['cummulative_revenue']=coffee['revenue'].cumsum()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue  \
# 0      Monday    Espresso   15.000000   4.99        5.99   124.75
# 1      Monday       Latte   15.000000   4.99        5.99    74.85
# 2     Tuesday    Espresso   21.666667   4.99        5.99   149.70
# 3     Tuesday       Latte   28.333333   4.99        5.99    99.80
# 4   Wednesday    Espresso   35.000000   4.99        5.99   174.65
# 5   Wednesday       Latte   25.000000   4.99        5.99   124.75
# 6    Thursday    Espresso   40.000000   4.99        5.99   199.60
# 7    Thursday       Latte   30.000000   4.99        5.99   149.70
# 8      Friday    Espresso   45.000000   4.99        5.99   224.55
# 9      Friday       Latte   35.000000   4.99        5.99   174.65
# 10   Saturday    Espresso   45.000000   4.99        5.99   224.55
# 11   Saturday       Latte   35.000000   4.99        5.99   174.65
# 12     Sunday    Espresso   45.000000   4.99        5.99   224.55
# ...

# %%
latte=coffee[coffee['Coffee Type']=="Latte"].copy()
latte['3day']=latte['Units Sold'].rolling(3).sum()

# %%
latte
# Out:
#           Day Coffee Type  Units Sold  price  new__price  revenue  \
# 1      Monday       Latte   15.000000   4.99        5.99    74.85
# 3     Tuesday       Latte   28.333333   4.99        5.99    99.80
# 5   Wednesday       Latte   25.000000   4.99        5.99   124.75
# 7    Thursday       Latte   30.000000   4.99        5.99   149.70
# 9      Friday       Latte   35.000000   4.99        5.99   174.65
# 11   Saturday       Latte   35.000000   4.99        5.99   174.65
# 13     Sunday       Latte   35.000000   4.99        5.99   174.65
#
#     yesterday_revenue  pct_change  cummulative_revenue        3day
# 1                 NaN         NaN                199.6         NaN
# 3               74.85  133.333333                449.1         NaN
# 5               99.80  125.000000                748.5   68.333333
# 7              124.75  120.000000               1097.8   83.333333
# 9              149.70  116.666667               1497.0   90.000000
# ...

# %%
pd.__version__
# Out:
# '2.3.3'
