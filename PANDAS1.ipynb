# %%
#pandas library
#useful for data manipulation
#used for only structured data

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Chaitanya\OneDrive\Desktop\NTIN SIR\traffic.csv",sep='$')

# %%
data
# Out:
#     nitin  45  m  34000   delhi
# 0    neha  65  f  76000  mumbai
# 1    aman  75  m  44000   delhi
# 2    ravi  47  m  77000    pune
# 3  vishal  91  m  87000   delhi
# 4  shruti  54  f  27000   delhi
# 5   sneha  75  f  19000    pune
# 6    amit  84  m  75000    pune
# 7  deepak  38  m  58000    pune
# 8   rajan  84  m  65000  mumbai
# 9  shweta  59  f  82000  mumbai

# %%
data.shape
# Out:
# (10, 5)

# %%
cols=['Names','Age','Gender','Salary','City']
data=pd.read_csv(r"C:\Users\Chaitanya\OneDrive\Desktop\NTIN SIR\traffic.csv",sep='$',names=cols)

# %%
data
# Out:
#      Names  Age Gender  Salary    City
# 0    nitin   45      m   34000   delhi
# 1     neha   65      f   76000  mumbai
# 2     aman   75      m   44000   delhi
# 3     ravi   47      m   77000    pune
# 4   vishal   91      m   87000   delhi
# 5   shruti   54      f   27000   delhi
# 6    sneha   75      f   19000    pune
# 7     amit   84      m   75000    pune
# 8   deepak   38      m   58000    pune
# 9    rajan   84      m   65000  mumbai
# 10  shweta   59      f   82000  mumbai

# %%
data.shape[0]
# Out:
# 11

# %%
data.shape[1]
# Out:
# 5

# %%
data.columns
# Out:
# Index(['Names', 'Age', 'Gender', 'Salary', 'City'], dtype='object')

# %%
data.head()
# Out:
#     Names  Age Gender  Salary    City
# 0   nitin   45      m   34000   delhi
# 1    neha   65      f   76000  mumbai
# 2    aman   75      m   44000   delhi
# 3    ravi   47      m   77000    pune
# 4  vishal   91      m   87000   delhi

# %%
data.tail()
# Out:
#      Names  Age Gender  Salary    City
# 6    sneha   75      f   19000    pune
# 7     amit   84      m   75000    pune
# 8   deepak   38      m   58000    pune
# 9    rajan   84      m   65000  mumbai
# 10  shweta   59      f   82000  mumbai

# %%
data.columns
# Out:
# Index(['Names', 'Age', 'Gender', 'Salary', 'City'], dtype='object')

# %%
data['Salary']
# Out:
# 0     34000
# 1     76000
# 2     44000
# 3     77000
# 4     87000
# 5     27000
# 6     19000
# 7     75000
# 8     58000
# 9     65000
# 10    82000
# Name: Salary, dtype: int64

# %%
data['Age'][4]
# Out:
# np.int64(91)

# %%
data['Age'][0]
# Out:
# np.int64(45)

# %%
data['Names'][2]
# Out:
# 'aman'

# %%
data['Gender'].unique()
# Out:
# array(['m', 'f'], dtype=object)

# %%
len(data['City'].unique())
# Out:
# 3

# %%
data.head()
# Out:
#     Names  Age Gender  Salary    City
# 0   nitin   45      m   34000   delhi
# 1    neha   65      f   76000  mumbai
# 2    aman   75      m   44000   delhi
# 3    ravi   47      m   77000    pune
# 4  vishal   91      m   87000   delhi

# %%
data.tail()
# Out:
#      Names  Age Gender  Salary    City
# 6    sneha   75      f   19000    pune
# 7     amit   84      m   75000    pune
# 8   deepak   38      m   58000    pune
# 9    rajan   84      m   65000  mumbai
# 10  shweta   59      f   82000  mumbai

# %%
data
# Out:
#      Names  Age Gender  Salary    City
# 0    nitin   45      m   34000   delhi
# 1     neha   65      f   76000  mumbai
# 2     aman   75      m   44000   delhi
# 3     ravi   47      m   77000    pune
# 4   vishal   91      m   87000   delhi
# 5   shruti   54      f   27000   delhi
# 6    sneha   75      f   19000    pune
# 7     amit   84      m   75000    pune
# 8   deepak   38      m   58000    pune
# 9    rajan   84      m   65000  mumbai
# 10  shweta   59      f   82000  mumbai

# %%
data['Age'].max()
# Out:
# 91

# %%
data['Age'].mean()
# Out:
# np.float64(65.18181818181819)

# %%
data['Age'].sum()
# Out:
# np.int64(717)

# %%
data.columns=['name','age','gen','sal','state']

# %%
data
# Out:
#       name  age gen    sal   state
# 0    nitin   45   m  34000   delhi
# 1     neha   65   f  76000  mumbai
# 2     aman   75   m  44000   delhi
# 3     ravi   47   m  77000    pune
# 4   vishal   91   m  87000   delhi
# 5   shruti   54   f  27000   delhi
# 6    sneha   75   f  19000    pune
# 7     amit   84   m  75000    pune
# 8   deepak   38   m  58000    pune
# 9    rajan   84   m  65000  mumbai
# 10  shweta   59   f  82000  mumbai

# %%
axis=0 row
axis=1 col
# Out:
#   Cell In[95], line 1
#     axis=0 row
#            ^
# SyntaxError: invalid syntax

# %%
data.drop(3,axis=0)
# Out:
#       name  age gen    sal   state
# 0    nitin   45   m  34000   delhi
# 1     neha   65   f  76000  mumbai
# 2     aman   75   m  44000   delhi
# 4   vishal   91   m  87000   delhi
# 5   shruti   54   f  27000   delhi
# 6    sneha   75   f  19000    pune
# 7     amit   84   m  75000    pune
# 8   deepak   38   m  58000    pune
# 9    rajan   84   m  65000  mumbai
# 10  shweta   59   f  82000  mumbai

# %%
data=data.drop('gen',axis=1)

# %%
data
# Out:
#       name  age    sal   state
# 0    nitin   45  34000   delhi
# 1     neha   65  76000  mumbai
# 2     aman   75  44000   delhi
# 3     ravi   47  77000    pune
# 4   vishal   91  87000   delhi
# 5   shruti   54  27000   delhi
# 6    sneha   75  19000    pune
# 7     amit   84  75000    pune
# 8   deepak   38  58000    pune
# 9    rajan   84  65000  mumbai
# 10  shweta   59  82000  mumbai

# %%
data.reset_index(drop=True)
# Out:
#       name  age    sal   state
# 0    nitin   45  34000   delhi
# 1     neha   65  76000  mumbai
# 2     aman   75  44000   delhi
# 3     ravi   47  77000    pune
# 4   vishal   91  87000   delhi
# 5   shruti   54  27000   delhi
# 6    sneha   75  19000    pune
# 7     amit   84  75000    pune
# 8   deepak   38  58000    pune
# 9    rajan   84  65000  mumbai
# 10  shweta   59  82000  mumbai

# %%
data
# Out:
#       name  age    sal   state
# 0    nitin   45  34000   delhi
# 1     neha   65  76000  mumbai
# 2     aman   75  44000   delhi
# 3     ravi   47  77000    pune
# 4   vishal   91  87000   delhi
# 5   shruti   54  27000   delhi
# 6    sneha   75  19000    pune
# 7     amit   84  75000    pune
# 8   deepak   38  58000    pune
# 9    rajan   84  65000  mumbai
# 10  shweta   59  82000  mumbai

# %%
data.sort_values('age')
# Out:
#       name  age    sal   state
# 8   deepak   38  58000    pune
# 0    nitin   45  34000   delhi
# 3     ravi   47  77000    pune
# 5   shruti   54  27000   delhi
# 10  shweta   59  82000  mumbai
# 1     neha   65  76000  mumbai
# 2     aman   75  44000   delhi
# 6    sneha   75  19000    pune
# 7     amit   84  75000    pune
# 9    rajan   84  65000  mumbai
# 4   vishal   91  87000   delhi

# %%
data.sort_values('age',ascending=False)
# Out:
#       name  age    sal   state
# 4   vishal   91  87000   delhi
# 7     amit   84  75000    pune
# 9    rajan   84  65000  mumbai
# 2     aman   75  44000   delhi
# 6    sneha   75  19000    pune
# 1     neha   65  76000  mumbai
# 10  shweta   59  82000  mumbai
# 5   shruti   54  27000   delhi
# 3     ravi   47  77000    pune
# 0    nitin   45  34000   delhi
# 8   deepak   38  58000    pune

# %%
data = pd.read_csv('new_file.csv') # No sep needed, comma is default
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 data = pd.read_csv('new_file.csv') # No sep needed, comma is default
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd
import os

# This finds your desktop path automatically
desktop = os.path.join(os.path.join(os.environ['USERPROFILE']), 'Desktop')
file_path = os.path.join(desktop, 'traffic.csv')

# Now read it using your $ separator
data = pd.read_csv(file_path, sep='$')
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[136], line 9
#       6 file_path = os.path.join(desktop, 'traffic.csv')
#       8 # Now read it using your $ separator
# ----> 9 data = pd.read_csv(file_path, sep='$')
#      10 print(data.head())
#
# ...

# %%
data
# Out:
#                          0
# 0       name,age,sal,state
# 1     nitin,45,34000,delhi
# 2     neha,65,76000,mumbai
# 3      aman,75,44000,delhi
# 4       ravi,47,77000,pune
# 5    vishal,91,87000,delhi
# 6    shruti,54,27000,delhi
# 7      sneha,75,19000,pune
# 8       amit,84,75000,pune
# 9     deepak,38,58000,pune
# 10   rajan,84,65000,mumbai
# 11  shweta,59,82000,mumbai
