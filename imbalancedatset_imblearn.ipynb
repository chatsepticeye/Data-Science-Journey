# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Chaitanya\Downloads\archive (4)\Titanic-Dataset.csv")

# %%
data.drop(['PassengerId','Ticket','Fare','Cabin'],axis=1,inplace=True)

# %%
data=data.bfill().ffill()

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Embarked    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20)

# %%
from sklearn.preprocessing import LabelEncoder
for i in data.columns:
    le=LabelEncoder()
    if(data[i].dtype=='object'):
        data[i]=le.fit_transform(data[i])

# %%
x=data.iloc[:,1:]
y=data.iloc[:,0]

# %%
#undersampling    majority data will reduce
#oversampling     minority data will increase
#NearMiss    undersampling   reducing the majority class data
#SMOTE       oversampling    increase the minority class data

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss

# %%
ytrain.value_counts()
# Out:
# Survived
# 0    447
# 1    265
# Name: count, dtype: int64

# %%
sm=SMOTE(sampling_strategy=1)

# %%
newxtrain,newytrain=sm.fit_resample(xtrain,ytrain)

# %%
newytrain.value_counts()
# Out:
# Survived
# 0    447
# 1    447
# Name: count, dtype: int64

# %%
nm=NearMiss()

# %%
nx,ny=nm.fit_resample(xtrain,ytrain)
